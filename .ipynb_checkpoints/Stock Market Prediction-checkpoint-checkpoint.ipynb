# %% [markdown]
# Import necessary libraries below

# %%
import glob
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras import layers, models, Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense
import time
import math
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# Define plotting options

# %%
# %matplotlib inline
plt.style.use("ggplot")

# %% [markdown]
# Explore the existing data, finding the paths to the available dataset companies

# %%
csv_files = list(glob.glob("*stock_market_data/sp500/csv/*.csv", recursive = True))
csv_files[:5]
# Out:
# ['stock_market_data\\sp500\\csv\\A.csv',
#  'stock_market_data\\sp500\\csv\\AAL.csv',
#  'stock_market_data\\sp500\\csv\\AAP.csv',
#  'stock_market_data\\sp500\\csv\\AAPL.csv',
#  'stock_market_data\\sp500\\csv\\ABBV.csv']

# %% [markdown]
# Define below creation of different models through functions in Python

# %%
def create_best_cnn_model(input_shape):
    # CNN model
    model = Sequential()
    model.add(Conv1D(filters=256, kernel_size=5, activation='relu', input_shape=(input_shape,1)))
    model.add(Flatten())
    model.add(Dense(150, activation='relu'))
    model.add(Dense(1))  # Output layer
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mape'])
    return model

def create_general_cnn_model(input_shape, individual_params):
    model = Sequential()
    model.add(Conv1D(filters=individual_params['number_of_filters'], 
                     kernel_size= individual_params['kernel_size'], 
                     activation= individual_params['activation_in_convolution'], 
                     input_shape=(input_shape,1)))
    model.add(Flatten())
    model.add(Dense(individual_params['nodes_in_dense_layer'], activation=individual_params['activation_in_dense_layer']))
    model.add(Dense(1))  # Output layer
    # Compile the model
    model.compile(optimizer=individual_params['optimizer'], loss=individual_params['loss'], metrics=['mape'])
    return model

def craete_lstm_model(input_shape):
    # Build LSTM model
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(input_Shape, 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# Store the paths to all the companies we have in our dataset

# %%
prices_dict_path = {}

for file in csv_files:
    splits_of_path = file.split("\\")
    company_part = splits_of_path[-1].split(".csv")[0]
    prices_dict_path[company_part] = file

# %% [markdown]
# Define plotting function to show results in training for the metrics used in training vs validation

# %%
def plot_graph(epochs, validation_values, train_values, metric):
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, train_values, 'b', label=f'Training {metric}')
    plt.plot(epochs, validation_values, 'r', label=f'Validation {metric}')
    plt.title(f'Training and Validation {metric}')
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend()
    plt.show()

# %% [markdown]
# Create two different training functions: one for the user to manually train a configuration, which will allow the user to visualize the validation vs training and one to use in the evolutionary process, as that would not require plotting graphs, making it lightweight and also allowing for an early stop. The individual params lets the user pass in manual_training the configuration of the network, if not it will just use the default best.

# %%
def evolutionary_training_for_company(company_name, model_creation, scaler, individual_params):
    csv_path = prices_dict_path[company_name]
    data = pd.read_csv(csv_path, delimiter=',', usecols=['Open', 'High', 'Low', 'Close', 'Volume'])
    epochs = 1000
    epoch_points = range(1,epochs+1)
    # Create EarlyStopping callback
    early_stopping = EarlyStopping(monitor='val_mape', patience=100, restore_best_weights=True)
    # It is important to scale values in the training data, as this helps in improving the accuracy o the prediction values, helping use achieve
    # results closer to the real values. We use minmaxscaler, which will transform to follow a normal distribution.
    X = scaler.fit_transform(data)
    X = X[:-1]
    y = data['Close']
    y = y[1:]
    # this is following Train-Validation Split., where we perform validation on unseen data and try to evaluate the performance of the model.
    # it is important that we avoid problems such as overfitting when training the neural network.
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    
    # Reshape data for CNN input
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1], 1))
    
    model = model_creation(X_train.shape[1], individual_params)
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=50, validation_data=(X_val, y_val), verbose=0, callbacks=[early_stopping])

    # Early stopping
    if len(history.history['val_mape']) < epochs:
        epoch_points = range(1,len(history.history['val_mape'])+1)
        #print(f"The training stopped after {len(history.history['val_mape'])} epochs since it started stagnating")
    
    return history.history['val_mape'][-1], model

def manual_training_for_company(company_name, model_creation, scaler, individual_params=None):
    csv_path = prices_dict_path[company_name]
    data = pd.read_csv(csv_path, delimiter=',', usecols=['Open', 'High', 'Low', 'Close', 'Volume'])
    epochs = 250
    epoch_points = range(1,epochs+1)
    
    # It is important to scale values in the training data, as this helps in improving the accuracy o the prediction values, helping use achieve
    # results closer to the real values. We use minmaxscaler, which will transform to follow a normal distribution.
    X = scaler.fit_transform(data)
    X = X[:-1]
    y = data['Close']
    y = y[1:]
    # this is following Train-Validation Split., where we perform validation on unseen data and try to evaluate the performance of the model.
    # it is important that we avoid problems such as overfitting when training the neural network.
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    
    # Reshape data for CNN input
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1], 1))
    
    model = model_creation(X_train.shape[1]) if individual_params is None else model_creation(X_train.shape[1],individual_params)
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=50, validation_data=(X_val, y_val), verbose=1)
    
    # Plot MAE
    plot_graph(epoch_points, history.history['val_mape'], history.history['mape'], 'MAPE')
    
    # Plot losses
    plot_graph(epoch_points, history.history['val_loss'], history.history['loss'], "LOSS")
    
    return history.history['val_mape'][-1], model

# %%
# For running the manual_training we can do something like the code below
scaler = MinMaxScaler()
_,model = manual_training_for_company("IBM", create_best_cnn_model, scaler)
# Out:
# Epoch 1/250
# 214/214 [==============================] - 1s 2ms/step - loss: 1210.5018 - mape: 51.5962 - val_loss: 36.5622 - val_mape: 3.6201
# Epoch 2/250
# 214/214 [==============================] - 0s 2ms/step - loss: 2.2882 - mape: 2.9276 - val_loss: 4.7028 - val_mape: 1.0655
# Epoch 3/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4207 - mape: 1.4686 - val_loss: 4.8276 - val_mape: 1.0782
# Epoch 4/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3877 - mape: 1.3324 - val_loss: 4.9168 - val_mape: 1.1181
# Epoch 5/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3826 - mape: 1.3214 - val_loss: 4.5533 - val_mape: 1.0417
# Epoch 6/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3831 - mape: 1.3304 - val_loss: 4.5805 - val_mape: 1.0444
# Epoch 7/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3856 - mape: 1.3232 - val_loss: 4.6671 - val_mape: 1.0559
# Epoch 8/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3934 - mape: 1.3376 - val_loss: 4.5395 - val_mape: 1.0415
# Epoch 9/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3824 - mape: 1.3153 - val_loss: 4.5492 - val_mape: 1.0467
# Epoch 10/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3914 - mape: 1.3293 - val_loss: 4.8945 - val_mape: 1.1152
# Epoch 11/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4130 - mape: 1.3813 - val_loss: 4.7754 - val_mape: 1.0708
# Epoch 12/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3973 - mape: 1.3565 - val_loss: 4.6403 - val_mape: 1.0672
# Epoch 13/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4019 - mape: 1.3560 - val_loss: 4.5252 - val_mape: 1.0404
# Epoch 14/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3867 - mape: 1.3155 - val_loss: 4.6792 - val_mape: 1.0573
# Epoch 15/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4416 - mape: 1.4116 - val_loss: 5.4659 - val_mape: 1.2136
# Epoch 16/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4192 - mape: 1.4035 - val_loss: 5.6785 - val_mape: 1.2491
# Epoch 17/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4194 - mape: 1.3836 - val_loss: 4.6175 - val_mape: 1.0490
# Epoch 18/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4212 - mape: 1.3663 - val_loss: 4.8975 - val_mape: 1.1172
# Epoch 19/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4445 - mape: 1.4129 - val_loss: 4.5220 - val_mape: 1.0426
# Epoch 20/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4328 - mape: 1.4139 - val_loss: 4.6039 - val_mape: 1.0608
# Epoch 21/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3955 - mape: 1.3604 - val_loss: 4.5248 - val_mape: 1.0388
# Epoch 22/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4238 - mape: 1.4015 - val_loss: 5.0948 - val_mape: 1.1521
# Epoch 23/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4257 - mape: 1.3940 - val_loss: 5.9073 - val_mape: 1.2856
# Epoch 24/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4813 - mape: 1.4774 - val_loss: 4.5540 - val_mape: 1.0405
# Epoch 25/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4110 - mape: 1.3749 - val_loss: 6.1604 - val_mape: 1.2731
# Epoch 26/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4915 - mape: 1.5072 - val_loss: 4.7500 - val_mape: 1.0674
# Epoch 27/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4855 - mape: 1.4654 - val_loss: 4.6432 - val_mape: 1.0523
# Epoch 28/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4717 - mape: 1.4809 - val_loss: 4.5202 - val_mape: 1.0453
# Epoch 29/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4680 - mape: 1.4523 - val_loss: 4.4843 - val_mape: 1.0357
# Epoch 30/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4607 - mape: 1.4248 - val_loss: 5.4361 - val_mape: 1.1691
# Epoch 31/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4555 - mape: 1.4604 - val_loss: 4.5371 - val_mape: 1.0375
# Epoch 32/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4922 - mape: 1.4673 - val_loss: 5.4939 - val_mape: 1.1803
# Epoch 33/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4029 - mape: 1.3931 - val_loss: 4.5389 - val_mape: 1.0506
# Epoch 34/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4403 - mape: 1.4139 - val_loss: 4.8220 - val_mape: 1.1068
# Epoch 35/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4556 - mape: 1.4547 - val_loss: 5.1119 - val_mape: 1.1246
# Epoch 36/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.5003 - mape: 1.5224 - val_loss: 7.4653 - val_mape: 1.4569
# Epoch 37/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4400 - mape: 1.4156 - val_loss: 5.7245 - val_mape: 1.2602
# Epoch 38/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4547 - mape: 1.4907 - val_loss: 5.3310 - val_mape: 1.1962
# Epoch 39/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4023 - mape: 1.4055 - val_loss: 5.7909 - val_mape: 1.2708
# Epoch 40/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4782 - mape: 1.5286 - val_loss: 4.4370 - val_mape: 1.0258
# Epoch 41/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4950 - mape: 1.4919 - val_loss: 5.0383 - val_mape: 1.1116
# Epoch 42/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4233 - mape: 1.4077 - val_loss: 5.9965 - val_mape: 1.3024
# Epoch 43/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.5053 - mape: 1.5089 - val_loss: 6.0892 - val_mape: 1.3178
# Epoch 44/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4252 - mape: 1.4105 - val_loss: 4.4265 - val_mape: 1.0264
# Epoch 45/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4968 - mape: 1.5211 - val_loss: 4.9615 - val_mape: 1.1327
# Epoch 46/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4113 - mape: 1.3877 - val_loss: 5.6434 - val_mape: 1.2027
# Epoch 47/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4616 - mape: 1.4550 - val_loss: 4.4086 - val_mape: 1.0241
# Epoch 48/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4680 - mape: 1.4416 - val_loss: 5.3518 - val_mape: 1.1606
# Epoch 49/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4309 - mape: 1.4307 - val_loss: 4.7994 - val_mape: 1.1057
# Epoch 50/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4326 - mape: 1.4419 - val_loss: 4.7607 - val_mape: 1.0709
# Epoch 51/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4569 - mape: 1.4307 - val_loss: 4.8919 - val_mape: 1.1207
# Epoch 52/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4158 - mape: 1.3943 - val_loss: 4.6202 - val_mape: 1.0505
# Epoch 53/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4624 - mape: 1.4692 - val_loss: 4.3957 - val_mape: 1.0211
# Epoch 54/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.5299 - mape: 1.5623 - val_loss: 4.9302 - val_mape: 1.0977
# Epoch 55/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4668 - mape: 1.4693 - val_loss: 4.3963 - val_mape: 1.0241
# Epoch 56/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4113 - mape: 1.4227 - val_loss: 4.3761 - val_mape: 1.0189
# Epoch 57/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4567 - mape: 1.4750 - val_loss: 4.4148 - val_mape: 1.0285
# Epoch 58/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.5103 - mape: 1.5503 - val_loss: 5.1495 - val_mape: 1.1312
# Epoch 59/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4262 - mape: 1.4361 - val_loss: 4.6582 - val_mape: 1.0801
# Epoch 60/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3841 - mape: 1.4084 - val_loss: 4.4666 - val_mape: 1.0280
# Epoch 61/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4285 - mape: 1.4133 - val_loss: 4.9262 - val_mape: 1.1290
# Epoch 62/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4755 - mape: 1.5139 - val_loss: 4.3652 - val_mape: 1.0188
# Epoch 63/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3813 - mape: 1.3707 - val_loss: 5.2438 - val_mape: 1.1846
# Epoch 64/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4043 - mape: 1.4205 - val_loss: 5.0537 - val_mape: 1.1178
# Epoch 65/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4171 - mape: 1.4517 - val_loss: 4.7242 - val_mape: 1.0677
# Epoch 66/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3909 - mape: 1.3847 - val_loss: 4.4082 - val_mape: 1.0205
# Epoch 67/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4228 - mape: 1.4406 - val_loss: 4.4163 - val_mape: 1.0313
# Epoch 68/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3681 - mape: 1.3746 - val_loss: 4.3485 - val_mape: 1.0161
# Epoch 69/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4118 - mape: 1.4417 - val_loss: 4.4758 - val_mape: 1.0303
# Epoch 70/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4205 - mape: 1.4334 - val_loss: 5.1135 - val_mape: 1.1266
# Epoch 71/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4914 - mape: 1.4918 - val_loss: 5.3441 - val_mape: 1.1620
# Epoch 72/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4324 - mape: 1.4626 - val_loss: 4.4514 - val_mape: 1.0404
# Epoch 73/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4177 - mape: 1.3920 - val_loss: 10.2265 - val_mape: 1.8648
# Epoch 74/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4884 - mape: 1.4915 - val_loss: 4.5573 - val_mape: 1.0631
# Epoch 75/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4037 - mape: 1.3917 - val_loss: 4.7171 - val_mape: 1.0669
# Epoch 76/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3849 - mape: 1.4000 - val_loss: 5.3282 - val_mape: 1.1587
# Epoch 77/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3664 - mape: 1.3837 - val_loss: 4.3451 - val_mape: 1.0123
# Epoch 78/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3774 - mape: 1.3640 - val_loss: 5.5498 - val_mape: 1.2366
# Epoch 79/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3523 - mape: 1.3472 - val_loss: 5.7376 - val_mape: 1.2685
# Epoch 80/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3948 - mape: 1.4213 - val_loss: 4.7974 - val_mape: 1.1078
# Epoch 81/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4065 - mape: 1.3963 - val_loss: 4.3333 - val_mape: 1.0167
# Epoch 82/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3860 - mape: 1.3887 - val_loss: 4.4224 - val_mape: 1.0215
# Epoch 83/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3951 - mape: 1.4242 - val_loss: 4.3388 - val_mape: 1.0106
# Epoch 84/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3614 - mape: 1.3774 - val_loss: 5.6049 - val_mape: 1.2463
# Epoch 85/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4354 - mape: 1.4445 - val_loss: 5.3853 - val_mape: 1.2075
# Epoch 86/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3632 - mape: 1.3713 - val_loss: 4.4927 - val_mape: 1.0512
# Epoch 87/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3965 - mape: 1.3948 - val_loss: 4.4669 - val_mape: 1.0461
# Epoch 88/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3914 - mape: 1.3750 - val_loss: 4.6266 - val_mape: 1.0545
# Epoch 89/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3720 - mape: 1.4065 - val_loss: 4.2932 - val_mape: 1.0088
# Epoch 90/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3789 - mape: 1.3843 - val_loss: 4.5885 - val_mape: 1.0490
# Epoch 91/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4833 - mape: 1.4877 - val_loss: 5.0559 - val_mape: 1.1208
# Epoch 92/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3699 - mape: 1.4017 - val_loss: 4.2957 - val_mape: 1.0058
# Epoch 93/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4220 - mape: 1.5048 - val_loss: 4.3987 - val_mape: 1.0195
# Epoch 94/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4400 - mape: 1.4482 - val_loss: 4.8729 - val_mape: 1.0922
# Epoch 95/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3820 - mape: 1.3718 - val_loss: 4.3066 - val_mape: 1.0130
# Epoch 96/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3595 - mape: 1.3603 - val_loss: 4.3259 - val_mape: 1.0182
# Epoch 97/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3853 - mape: 1.4084 - val_loss: 4.3255 - val_mape: 1.0085
# Epoch 98/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4241 - mape: 1.4400 - val_loss: 4.5522 - val_mape: 1.0651
# Epoch 99/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3677 - mape: 1.3751 - val_loss: 5.2655 - val_mape: 1.1513
# Epoch 100/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3349 - mape: 1.3139 - val_loss: 5.1226 - val_mape: 1.1317
# Epoch 101/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3471 - mape: 1.3720 - val_loss: 5.7312 - val_mape: 1.2217
# Epoch 102/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4886 - mape: 1.5249 - val_loss: 4.3703 - val_mape: 1.0282
# Epoch 103/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3571 - mape: 1.3654 - val_loss: 5.1403 - val_mape: 1.1344
# Epoch 104/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3931 - mape: 1.4259 - val_loss: 5.5658 - val_mape: 1.2419
# Epoch 105/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3833 - mape: 1.4054 - val_loss: 4.8364 - val_mape: 1.0873
# Epoch 106/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4012 - mape: 1.4311 - val_loss: 5.0439 - val_mape: 1.1187
# Epoch 107/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4285 - mape: 1.4766 - val_loss: 6.8040 - val_mape: 1.3749
# Epoch 108/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3860 - mape: 1.4041 - val_loss: 4.2680 - val_mape: 1.0069
# Epoch 109/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3758 - mape: 1.3798 - val_loss: 4.3261 - val_mape: 1.0087
# Epoch 110/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4205 - mape: 1.4007 - val_loss: 4.7909 - val_mape: 1.1097
# Epoch 111/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3764 - mape: 1.3828 - val_loss: 5.2744 - val_mape: 1.1944
# Epoch 112/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3659 - mape: 1.3931 - val_loss: 4.2694 - val_mape: 1.0020
# Epoch 113/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4351 - mape: 1.4824 - val_loss: 4.6050 - val_mape: 1.0513
# Epoch 114/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3931 - mape: 1.3693 - val_loss: 6.5912 - val_mape: 1.4017
# Epoch 115/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4506 - mape: 1.4937 - val_loss: 4.3997 - val_mape: 1.0359
# Epoch 116/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3443 - mape: 1.3516 - val_loss: 4.2622 - val_mape: 1.0024
# Epoch 117/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3833 - mape: 1.3904 - val_loss: 4.4116 - val_mape: 1.0378
# Epoch 118/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3736 - mape: 1.3686 - val_loss: 4.4449 - val_mape: 1.0275
# Epoch 119/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3272 - mape: 1.3897 - val_loss: 4.7177 - val_mape: 1.0698
# Epoch 120/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3832 - mape: 1.3893 - val_loss: 4.8915 - val_mape: 1.1273
# Epoch 121/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3428 - mape: 1.3678 - val_loss: 4.2507 - val_mape: 1.0001
# Epoch 122/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3877 - mape: 1.3971 - val_loss: 4.2460 - val_mape: 0.9994
# Epoch 123/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3881 - mape: 1.4174 - val_loss: 5.6504 - val_mape: 1.2116
# Epoch 124/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3483 - mape: 1.3681 - val_loss: 4.4256 - val_mape: 1.0417
# Epoch 125/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3468 - mape: 1.3827 - val_loss: 6.7551 - val_mape: 1.3693
# Epoch 126/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3810 - mape: 1.4315 - val_loss: 5.2057 - val_mape: 1.1445
# Epoch 127/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3760 - mape: 1.3845 - val_loss: 5.9610 - val_mape: 1.2559
# Epoch 128/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3861 - mape: 1.4141 - val_loss: 4.2396 - val_mape: 0.9985
# Epoch 129/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3965 - mape: 1.4291 - val_loss: 5.7598 - val_mape: 1.2273
# Epoch 130/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3506 - mape: 1.3932 - val_loss: 4.6758 - val_mape: 1.0638
# Epoch 131/250
# 214/214 [==============================] - 1s 2ms/step - loss: 1.3617 - mape: 1.3756 - val_loss: 4.7274 - val_mape: 1.0985
# Epoch 132/250
# 214/214 [==============================] - 1s 2ms/step - loss: 1.3103 - mape: 1.3132 - val_loss: 5.5086 - val_mape: 1.1928
# Epoch 133/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3531 - mape: 1.3742 - val_loss: 4.2235 - val_mape: 0.9981
# Epoch 134/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3339 - mape: 1.3757 - val_loss: 4.5723 - val_mape: 1.0470
# Epoch 135/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3858 - mape: 1.4107 - val_loss: 4.2693 - val_mape: 1.0016
# Epoch 136/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3330 - mape: 1.3423 - val_loss: 4.4463 - val_mape: 1.0458
# Epoch 137/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3380 - mape: 1.3577 - val_loss: 4.5888 - val_mape: 1.0497
# Epoch 138/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3557 - mape: 1.4123 - val_loss: 4.3008 - val_mape: 1.0057
# Epoch 139/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3631 - mape: 1.4078 - val_loss: 4.3123 - val_mape: 1.0199
# Epoch 140/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4096 - mape: 1.4404 - val_loss: 8.7504 - val_mape: 1.6970
# Epoch 141/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3560 - mape: 1.3751 - val_loss: 4.5981 - val_mape: 1.0513
# Epoch 142/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3100 - mape: 1.3019 - val_loss: 4.9708 - val_mape: 1.1449
# Epoch 143/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3550 - mape: 1.3948 - val_loss: 4.2346 - val_mape: 0.9979
# Epoch 144/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3810 - mape: 1.4100 - val_loss: 4.2790 - val_mape: 1.0141
# Epoch 145/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3284 - mape: 1.3226 - val_loss: 4.2146 - val_mape: 0.9977
# Epoch 146/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3760 - mape: 1.4180 - val_loss: 5.3397 - val_mape: 1.2065
# Epoch 147/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3596 - mape: 1.4191 - val_loss: 4.7974 - val_mape: 1.0822
# Epoch 148/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.2845 - mape: 1.2792 - val_loss: 4.2207 - val_mape: 0.9965
# Epoch 149/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3680 - mape: 1.4018 - val_loss: 4.9824 - val_mape: 1.1104
# Epoch 150/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3655 - mape: 1.4206 - val_loss: 5.7074 - val_mape: 1.2205
# Epoch 151/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3337 - mape: 1.3803 - val_loss: 4.2224 - val_mape: 0.9968
# Epoch 152/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3090 - mape: 1.3553 - val_loss: 5.0922 - val_mape: 1.1288
# Epoch 153/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4048 - mape: 1.4204 - val_loss: 5.5199 - val_mape: 1.2370
# Epoch 154/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3260 - mape: 1.3454 - val_loss: 4.3083 - val_mape: 1.0074
# Epoch 155/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3712 - mape: 1.3811 - val_loss: 4.4396 - val_mape: 1.0271
# Epoch 156/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3142 - mape: 1.3351 - val_loss: 5.1491 - val_mape: 1.1361
# Epoch 157/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3413 - mape: 1.3772 - val_loss: 6.0483 - val_mape: 1.2705
# Epoch 158/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3514 - mape: 1.3701 - val_loss: 4.9506 - val_mape: 1.1410
# Epoch 159/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3759 - mape: 1.3970 - val_loss: 4.2950 - val_mape: 1.0053
# Epoch 160/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3032 - mape: 1.3401 - val_loss: 5.6279 - val_mape: 1.2091
# Epoch 161/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3462 - mape: 1.3862 - val_loss: 5.1327 - val_mape: 1.1731
# Epoch 162/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3002 - mape: 1.3213 - val_loss: 4.2344 - val_mape: 0.9976
# Epoch 163/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3391 - mape: 1.3582 - val_loss: 4.1999 - val_mape: 0.9982
# Epoch 164/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4085 - mape: 1.4113 - val_loss: 4.7092 - val_mape: 1.0687
# Epoch 165/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3811 - mape: 1.4316 - val_loss: 4.4536 - val_mape: 1.0299
# Epoch 166/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3352 - mape: 1.3086 - val_loss: 5.0785 - val_mape: 1.1641
# Epoch 167/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3581 - mape: 1.4240 - val_loss: 5.1191 - val_mape: 1.1332
# Epoch 168/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3545 - mape: 1.3950 - val_loss: 4.4162 - val_mape: 1.0249
# Epoch 169/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3933 - mape: 1.4491 - val_loss: 4.9304 - val_mape: 1.1037
# Epoch 170/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3142 - mape: 1.3301 - val_loss: 5.2167 - val_mape: 1.1869
# Epoch 171/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3662 - mape: 1.3778 - val_loss: 4.3311 - val_mape: 1.0108
# Epoch 172/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3855 - mape: 1.4431 - val_loss: 6.3810 - val_mape: 1.3202
# Epoch 173/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3360 - mape: 1.3531 - val_loss: 4.2973 - val_mape: 1.0199
# Epoch 174/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3219 - mape: 1.3341 - val_loss: 4.5434 - val_mape: 1.0676
# Epoch 175/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3283 - mape: 1.3591 - val_loss: 4.1858 - val_mape: 0.9941
# Epoch 176/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3315 - mape: 1.3445 - val_loss: 7.5958 - val_mape: 1.5498
# Epoch 177/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4638 - mape: 1.5271 - val_loss: 4.1867 - val_mape: 0.9963
# Epoch 178/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3534 - mape: 1.4016 - val_loss: 8.2394 - val_mape: 1.5713
# Epoch 179/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3554 - mape: 1.3938 - val_loss: 4.2430 - val_mape: 0.9988
# Epoch 180/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3522 - mape: 1.3742 - val_loss: 5.0002 - val_mape: 1.1503
# Epoch 181/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3181 - mape: 1.3329 - val_loss: 4.5006 - val_mape: 1.0374
# Epoch 182/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3043 - mape: 1.3223 - val_loss: 4.1862 - val_mape: 0.9941
# Epoch 183/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3697 - mape: 1.4775 - val_loss: 4.6206 - val_mape: 1.0824
# Epoch 184/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3514 - mape: 1.3890 - val_loss: 4.1756 - val_mape: 0.9922
# Epoch 185/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4023 - mape: 1.4552 - val_loss: 4.1698 - val_mape: 0.9932
# Epoch 186/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3310 - mape: 1.3232 - val_loss: 4.4158 - val_mape: 1.0248
# Epoch 187/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4034 - mape: 1.4609 - val_loss: 4.4445 - val_mape: 1.0287
# Epoch 188/250
# 214/214 [==============================] - 1s 3ms/step - loss: 1.3348 - mape: 1.3590 - val_loss: 4.2814 - val_mape: 1.0181
# Epoch 189/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3212 - mape: 1.3444 - val_loss: 4.1826 - val_mape: 0.9970
# Epoch 190/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3000 - mape: 1.3018 - val_loss: 4.3600 - val_mape: 1.0339
# Epoch 191/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3484 - mape: 1.3785 - val_loss: 4.1688 - val_mape: 0.9920
# Epoch 192/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3217 - mape: 1.3395 - val_loss: 4.7443 - val_mape: 1.0766
# Epoch 193/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3543 - mape: 1.3620 - val_loss: 4.9591 - val_mape: 1.1084
# Epoch 194/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3110 - mape: 1.3189 - val_loss: 4.3705 - val_mape: 1.0181
# Epoch 195/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3456 - mape: 1.4028 - val_loss: 4.2088 - val_mape: 0.9944
# Epoch 196/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4205 - mape: 1.4222 - val_loss: 4.1870 - val_mape: 0.9980
# Epoch 197/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3392 - mape: 1.3328 - val_loss: 4.1793 - val_mape: 0.9966
# Epoch 198/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3326 - mape: 1.3463 - val_loss: 4.2754 - val_mape: 1.0036
# Epoch 199/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3967 - mape: 1.4365 - val_loss: 4.7482 - val_mape: 1.0775
# Epoch 200/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3795 - mape: 1.4344 - val_loss: 4.2867 - val_mape: 1.0045
# Epoch 201/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3495 - mape: 1.3564 - val_loss: 5.8865 - val_mape: 1.2497
# Epoch 202/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3131 - mape: 1.3339 - val_loss: 4.1895 - val_mape: 0.9994
# Epoch 203/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3560 - mape: 1.3869 - val_loss: 4.5829 - val_mape: 1.0766
# Epoch 204/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.2937 - mape: 1.3196 - val_loss: 4.5129 - val_mape: 1.0636
# Epoch 205/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.2973 - mape: 1.3448 - val_loss: 7.5895 - val_mape: 1.5459
# Epoch 206/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4421 - mape: 1.5666 - val_loss: 5.1722 - val_mape: 1.1403
# Epoch 207/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3295 - mape: 1.3497 - val_loss: 4.4251 - val_mape: 1.0272
# Epoch 208/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3104 - mape: 1.3528 - val_loss: 4.1897 - val_mape: 0.9998
# Epoch 209/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3563 - mape: 1.4274 - val_loss: 4.6158 - val_mape: 1.0577
# Epoch 210/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3381 - mape: 1.3779 - val_loss: 4.5467 - val_mape: 1.0706
# Epoch 211/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3520 - mape: 1.3782 - val_loss: 4.5239 - val_mape: 1.0415
# Epoch 212/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3553 - mape: 1.4152 - val_loss: 4.6925 - val_mape: 1.0981
# Epoch 213/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3163 - mape: 1.3135 - val_loss: 5.0011 - val_mape: 1.1159
# Epoch 214/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3394 - mape: 1.3834 - val_loss: 5.5636 - val_mape: 1.2031
# Epoch 215/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3141 - mape: 1.3678 - val_loss: 4.2213 - val_mape: 0.9962
# Epoch 216/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3125 - mape: 1.3517 - val_loss: 4.1606 - val_mape: 0.9921
# Epoch 217/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3054 - mape: 1.3570 - val_loss: 5.9450 - val_mape: 1.3069
# Epoch 218/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3657 - mape: 1.4282 - val_loss: 4.2085 - val_mape: 1.0046
# Epoch 219/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3760 - mape: 1.4158 - val_loss: 5.2068 - val_mape: 1.1494
# Epoch 220/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3099 - mape: 1.3315 - val_loss: 4.3358 - val_mape: 1.0300
# Epoch 221/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3057 - mape: 1.3288 - val_loss: 4.7746 - val_mape: 1.0785
# Epoch 222/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.2959 - mape: 1.3134 - val_loss: 4.5363 - val_mape: 1.0440
# Epoch 223/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3671 - mape: 1.4139 - val_loss: 4.1588 - val_mape: 0.9907
# Epoch 224/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3060 - mape: 1.3157 - val_loss: 4.2786 - val_mape: 1.0037
# Epoch 225/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3958 - mape: 1.4301 - val_loss: 6.5248 - val_mape: 1.3978
# Epoch 226/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3537 - mape: 1.3744 - val_loss: 4.3570 - val_mape: 1.0153
# Epoch 227/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3409 - mape: 1.3753 - val_loss: 4.5817 - val_mape: 1.0776
# Epoch 228/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.4026 - mape: 1.4465 - val_loss: 4.4258 - val_mape: 1.0260
# Epoch 229/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.2985 - mape: 1.3139 - val_loss: 4.1539 - val_mape: 0.9909
# Epoch 230/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3536 - mape: 1.4046 - val_loss: 5.2280 - val_mape: 1.1899
# Epoch 231/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3069 - mape: 1.3339 - val_loss: 4.1850 - val_mape: 0.9919
# Epoch 232/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.2912 - mape: 1.3358 - val_loss: 4.6128 - val_mape: 1.0838
# Epoch 233/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3692 - mape: 1.3710 - val_loss: 4.6313 - val_mape: 1.0586
# Epoch 234/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3577 - mape: 1.4035 - val_loss: 4.3591 - val_mape: 1.0349
# Epoch 235/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3947 - mape: 1.4337 - val_loss: 4.6819 - val_mape: 1.0673
# Epoch 236/250
# 214/214 [==============================] - 0s 1ms/step - loss: 1.3426 - mape: 1.3891 - val_loss: 5.9200 - val_mape: 1.2555
# Epoch 237/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.4013 - mape: 1.4779 - val_loss: 4.1820 - val_mape: 0.9915
# Epoch 238/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3142 - mape: 1.3429 - val_loss: 4.1462 - val_mape: 0.9889
# Epoch 239/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3332 - mape: 1.3302 - val_loss: 4.4516 - val_mape: 1.0300
# Epoch 240/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.2991 - mape: 1.3003 - val_loss: 4.2370 - val_mape: 1.0113
# Epoch 241/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3759 - mape: 1.4111 - val_loss: 4.3910 - val_mape: 1.0207
# Epoch 242/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3700 - mape: 1.4382 - val_loss: 4.8025 - val_mape: 1.1175
# Epoch 243/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.2949 - mape: 1.3059 - val_loss: 4.4318 - val_mape: 1.0275
# Epoch 244/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3386 - mape: 1.3910 - val_loss: 5.2129 - val_mape: 1.1492
# Epoch 245/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3406 - mape: 1.3761 - val_loss: 7.6897 - val_mape: 1.5081
# Epoch 246/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3678 - mape: 1.4253 - val_loss: 6.6765 - val_mape: 1.4189
# Epoch 247/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3932 - mape: 1.4232 - val_loss: 4.9650 - val_mape: 1.1109
# Epoch 248/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3147 - mape: 1.3345 - val_loss: 4.1831 - val_mape: 1.0000
# Epoch 249/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.3001 - mape: 1.3194 - val_loss: 4.2429 - val_mape: 0.9995
# Epoch 250/250
# 214/214 [==============================] - 0s 2ms/step - loss: 1.2985 - mape: 1.3366 - val_loss: 4.1683 - val_mape: 0.9901

# %% [markdown]
# Creating a function to be able to evaluate on new data, that is not in our dataset.

# %%
def predict_and_evaluate_on_new_data(expected_prices, input_data, model, scaler):
    results = np.array(expected_prices)
    scaled_prediction_point = scaler.transform(input_data)
    scaled_prediction_point = np.reshape(scaled_prediction_point, (scaled_prediction_point.shape[0], scaled_prediction_point.shape[1], 1))
    predictions = model.predict(scaled_prediction_point)
    print(predictions)
    model.evaluate(scaled_prediction_point, results)

# %%
# How this function could be used is shown below:
microsoft_dict = pd.DataFrame({
    'Low': [377.44, 367.35, 326.36, 310.02, 319.21, 345.07, 333.45, 309.83, 285.67, 269.52],
    'Open': [383.76, 371.01, 332.38, 315.13, 320.26, 347.11, 334.36, 309.83, 287.23, 274.88],
    'Volume': [28942500, 27683900, 21072400, 26297600, 24342600, 41637700, 23084700, 26730300, 25824300, 34558700],
    'High': [384.30, 371.95, 333.83, 315.88, 322.41, 351.89, 337.96, 313.71, 290.45, 275.00],
    'Close': [378.85, 370.27, 327.73, 312.14, 321.01, 350.98, 335.02, 311.74, 287.18, 273.78]
})
results_for_microsoft = [380, 369.67, 328.65, 312.79, 324.04, 337.77, 328.60, 314.00, 284.34, 272.29]
predict_and_evaluate_on_new_data(results_for_microsoft, microsoft_dict, model, scaler)
# Out:
# 1/1 [==============================] - 0s 51ms/step
# [[379.93488]
#  [370.31177]
#  [328.9291 ]
#  [312.7844 ]
#  [321.3944 ]
#  [350.69446]
#  [335.8045 ]
#  [312.3863 ]
#  [288.10547]
#  [273.45685]]
# 1/1 [==============================] - 0s 235ms/step - loss: 24.4585 - mape: 0.9380

# %%
apple_dict = pd.DataFrame({
              'Low':
                  [129.64, 189.25, 134.13, 150.85, 152.88, 133.77, 150.10, 165.54, 170.76, 192.55, 193.59, 193.67, 191.42],
              'Open':
                  [130.92, 190.87, 134.83, 152.35, 153.11, 134.08, 151.28, 165.80, 170.98, 196.02, 193.63, 194.20, 193.11],
              'Volume':
                  [63814900, 24048300, 63646600, 59144100, 65573800, 58280400, 73695900, 47720200, 113316400, 47460200, 47477700, 53377300, 60896700],
              'High':
                  [132.42, 190.90, 137.29, 153.00, 155.50, 136.25, 153.40, 168.16, 174.30, 197.20, 195.00, 195.99, 193.49],
              'Close':
                  [131.86, 189.97, 135.94, 152.55, 155.33, 135.27, 152.59, 167.63, 173.57, 193.22, 194.27, 195.71, 193.18]
             })
results_for_apple = [129.31, 189.79, 135.21, 148.48, 153.71, 137.87, 152.99, 166.65, 173.50, 195.32, 195.71, 193.12, 193.4]
predict_and_evaluate_on_new_data(results_for_apple, apple_dict, model, scaler)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[132.03244]
#  [190.27104]
#  [136.44257]
#  [152.75705]
#  [155.50092]
#  [135.71428]
#  [152.90749]
#  [167.83052]
#  [174.26552]
#  [194.33801]
#  [194.82623]
#  [195.91837]
#  [193.40378]]
# 1/1 [==============================] - 0s 22ms/step - loss: 3.6056 - mape: 0.9607

# %%
ibm_dict = pd.DataFrame({
'Low':
                  [154.86, 156.02, 140.19, 146.82, 141.80, 132.59, 137.18, 121.10, 125.64, 122.88],
              'Open':
                  [155.44, 156.15, 140.90, 147.41, 143.05, 133.32, 137.27, 121.99, 126.58, 123.36],
              'Volume':
                  [2665800, 3568900, 3223900, 2562000, 4226400, 3507700, 3812600, 4189200, 5060500, 3812300],
              'High':
                  [155.75, 157.51, 141.70, 148.10, 143.37, 134.31, 138.80, 122.49, 127.25, 125.40],
              'Close':
                  [155.65, 156.41, 141.52, 146.91, 141.91, 134.24, 138.40, 122.02, 126.41, 125.29]
})
results_for_ibm = [156.41, 158.00, 142.03, 146.48, 141.87, 132.16, 137.48, 120.90, 126.09, 129.31]
predict_and_evaluate_on_new_data(results_for_ibm, ibm_dict, model, scaler)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# [[155.59465]
#  [156.7388 ]
#  [141.37021]
#  [147.24487]
#  [142.26578]
#  [133.99512]
#  [138.378  ]
#  [121.97406]
#  [126.49588]
#  [124.93363]]
# 1/1 [==============================] - 0s 20ms/step - loss: 2.8077 - mape: 0.9222

# %%
'''
372.56	374.41	370.04	373.54	373.54	17,693,500
196.10	197.08	193.50	194.68	194.68	46,432,100
153.30	153.97	152.10	153.84	153.84	36,258,000
17.53	17.74	17.42	17.59	17.59	30,411,700
8.15	8.31	7.99	8.29	8.29	48,630,400
251.90	254.80	248.55	254.50	254.50	109,344,200
140.77	142.03	140.47	141.80	141.80	18,082,400
352.98	356.41	349.21	354.09	354.09	15,269,500
6.83	6.93	6.67	6.89	6.89	1,508,800
#IBM, Microsoft, Apple, Amaazon, Palantir, NIO, Tesla, Google, Meta, Digital Turbine
# 22 december prediction closing
'''
predictions_for_different_companies = pd.DataFrame({
'Low':
                  [159.53,  370.04, 193.50, 153.97, 17.42, 7.99, 248.55, 140.47, 349.21, 6.67],
              'Open':
                  [160.59, 372.56, 196.10, 153.30, 17.53, 8.15, 251.90, 140.77, 352.98, 6.83],
              'Volume':
                  [2982300, 17693500, 46432100, 36258000, 30411700, 48630400, 109344200, 18082400, 15269500, 1508800],
              'High':
                  [161.08, 374.41, 197.08, 153.97, 17.74, 8.31, 254.80, 142.03, 356.41, 6.93],
              'Close':
                  [160.78,  373.54, 194.68, 153.84, 17.59, 8.29, 254.50, 141.80, 354.09, 6.89]
})
result = [160, 370, 195, 154.35, 18.21, 8.37, 253.21, 143.93, 352.21, 7]
predict_and_evaluate_on_new_data(result, predictions_for_different_companies, model, scaler)
# Out:
#   Cell In[42], line 7
#     140.77	142.03	140.47	141.80	141.80	18,082,400
#           	      	      	      	      	   ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
